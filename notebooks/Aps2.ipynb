# %% [markdown]
# ## Redes sociais - APS(2)

# %% [markdown]
# Diogo Duarte, Pedro Dannecker e Gabriel de Araújo Alves

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import csv
from graph_tool import Graph
import os
from graph_tool import util
# from netpixi.data.gt import *
# import netpixi
import netpixi
import pickle

from regression.integration.gt import *
from netpixi.integration.gt import *

# %% [markdown]
# ### Analisando os dados iniciais e Dataframe

# %%
import re
import pandas as pd

#first u have to open  the file and seperate every line like below:
# Foo='wiki-RfA.txt'
# picklestring = pickle.dumps(Foo)
# picklestring
df = open('wiki-RfA.txt', "r")

lines = df.readlines()
df_new=pickle.dumps(lines)
# print(df_new)
df.close()

# remove /n at the end of each line
for index, line in enumerate(lines):
       lines[index] = line.strip()
lines

# #creating a dataframe(consider u want to convert your data to 2 columns)

df_result = pd.DataFrame(columns=('SRC','TGT','VOT','RES','DAT','TXT'))
list_src=[]
list_tgt=[]
list_vot=[]
list_res=[]
list_dat=[]
list_txt=[]

for line in lines:
    if line.split(':')[0]=='SRC':
        list_src.append(line.split(':')[-1])
    elif line.split(':')[0]=='TGT':
        list_tgt.append(line.split(':')[-1])
    elif line.split(':')[0]=='VOT':
        list_vot.append(line.split(':')[-1])
    elif line.split(':')[0]=='RES':
        list_res.append(line.split(':')[-1])
    elif line.split(':')[0]=='DAT':
        list_dat.append(line.split(':')[-1])
    elif line.split(':')[0]=='TXT':
        list_txt.append(line.split(':')[-1])
    elif line.split(':')[0]==' ':
        pass

df_result['SRC']=list_src
df_result['TGT']=list_tgt
df_result['VOT']=list_vot
df_result['RES']=list_res
df_result['DAT']=list_dat
df_result['TXT']=list_txt

df_result.head()
# Out:
#           SRC  TGT VOT RES                DAT  \
# 0   Steel1943  BDD   1   1  13, 19 April 2013
# 1  Cuchullain  BDD   1   1  04, 20 April 2013
# 2   INeverCry  BDD   1   1  43, 19 April 2013
# 3   Cncmaster  BDD   1   1  11, 20 April 2013
# 4  Miniapolis  BDD   1   1  56, 20 April 2013
#
#                                                  TXT
# 0                           '''Support''' as co-nom.
# 1                      '''Support''' as nominator.--
# 2                            '''Support''' per noms.
# 3  '''Support''' per noms. BDD is a strong contri...
# 4  GOCE|Guild of Copy Editors]] (where we're both...

# %% [markdown]
# #### Transformando dados faltantes em desconhecidos

# %%
df_result['SRC']=df_result['SRC'].replace('','Unknown')
df_result['SRC'].value_counts()
# Out:
# Unknown           1661
# Siva1979          1232
# Mailer diablo      998
# Merovingian        916
# Wizardman          810
#                   ...
# Nunquam Dormio       1
# Eastlaw              1
# Yossiea              1
# P.wormer             1
# Nydigoveth           1
# Name: SRC, Length: 10415, dtype: int64

# %%
# df_result.drop(df_result[df_result['SRC']=='Unknown'].index,inplace=True)
df_result
# Out:
#                SRC           TGT VOT RES                DAT  \
# 0        Steel1943           BDD   1   1  13, 19 April 2013
# 1       Cuchullain           BDD   1   1  04, 20 April 2013
# 2        INeverCry           BDD   1   1  43, 19 April 2013
# 3        Cncmaster           BDD   1   1  11, 20 April 2013
# 4       Miniapolis           BDD   1   1  56, 20 April 2013
# ...            ...           ...  ..  ..                ...
# 198270         172  Vancouverguy   1   1     51, 2 Sep 2003
# 198271      Angela   WhisperToMe   1   1    45, 26 Nov 2003
# 198272       Jiang   WhisperToMe   1   1
# 198273     Pakaran   WhisperToMe   1   1     38, 5 Dec 2003
# 198274    Jimregan       Zanimum   1   1
#
#                                                       TXT
# 0                                '''Support''' as co-nom.
# 1                           '''Support''' as nominator.--
# 2                                 '''Support''' per noms.
# 3       '''Support''' per noms. BDD is a strong contri...
# 4       GOCE|Guild of Copy Editors]] (where we're both...
# ...                                                   ...
# 198270                                            Support
# 198271                                           Support.
# 198272                                        Support. --
# 198273  Support.  Age has nothing to do with maturity....
# 198274  Support - anyone who can write so much, and so...
#
# [198275 rows x 6 columns]

# %%
df_result['SRC'][df_result['SRC']=="Cuchullain"]
# Out:
# 1        Cuchullain
# 31171    Cuchullain
# Name: SRC, dtype: object

# %%
list_voters=df_result['SRC'].value_counts().index

# %% [markdown]
# #### Retirando valores neutros da  coluna VOT

# %%
df_result_new=df_result[df_result.VOT!='0']

# %%
list_targets=df_result_new.TGT.unique()

# %% [markdown]
# ### Criando o grafo

# %%
from netpixi.integration.gt import Graph

g = Graph() # dirigido

# %%
len(list_voters)
# Out:
# 10415

# %% [markdown]
# ### Criando vertices

# %%
for voter in list_voters:
#     print(type(voter))
      g.add_vertex(voter)

# %%
print('número de vértices de g:', g.num_vertices())
# Out:
# número de vértices de g: 10415

# %% [markdown]
# ### Adicionando propriedades aos vértices

# %%
values_voters=df_result['SRC'].value_counts().values
for voter,value in zip(list_voters,values_voters):
    g.add_gp(voter)
    value=int(value)
    g[voter]=value

# %% [markdown]
# ### Criando arestas

# %%
for i in range(len(list_voters)-1):
    
    if list_voters[i]>=list_voters[i+1]:
        g.add_edge(list_voters[i],list_voters[i+1])
    else:
        g.add_edge(list_voters[i+1],list_voters[i])

# %% [markdown]
# ### Analise exploratoria

# %% [markdown]
# #### a)número de vértices, número de arestas, densidade;

# %%
#número de vértices
n = g.num_vertices()
print('O número de vértices é {0}'.format(n))
# Out:
# O número de vértices é 10415

# %%
#número de arestas
m = g.num_edges()
print('O número de arestas é {0}'.format(m))
# Out:
# O número de arestas é 10414

# %%
##densidade
if g.is_directed():
    max_edges = n * (n - 1)
else:
    max_edges = n * (n - 1) // 2

d = m / max_edges
print('A densidade é {0}'.format(round(d,4)))
# Out:
# A densidade é 0.0002

# %% [markdown]
# #### b)estatísticas e histograma do degree. (não é necessário in-degree e out-degree)

# %%
data_targets = pd.DataFrame({k: list(v) for k, v in g.vp.items()})
data_targets
# Out:
#                    id
# 0             Unknown
# 1            Siva1979
# 2       Mailer diablo
# 3         Merovingian
# 4           Wizardman
# ...               ...
# 10410  Nunquam Dormio
# 10411         Eastlaw
# 10412         Yossiea
# 10413        P.wormer
# 10414      Nydigoveth
#
# [10415 rows x 1 columns]

# %%
degrees = []
for v in g.all_vertices():
    degrees.append(v.total_degree())

data_targets['degree'] = degrees
data_targets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10415 entries, 0 to 10414
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10415 non-null  object
#  1   degree  10415 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 162.9+ KB

# %%
import seaborn as sns
sns.histplot(data_targets['degree'])
data_targets['degree'].describe()
# Out:
# count    10415.000000
# mean         1.999808
# std          0.013857
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: degree, dtype: float64

# %% [markdown]
# ### Análise visual do grafo:

# %% [markdown]
# #### salve o grafo em um arquivo;

# %%
#gt_save(g,'Wiki-Rfa.net.gz')
g = gt_clean(g)

# %% [markdown]
# #### visualize o grafo a partir desse arquivo,algoritmo baseado em force-directed graph drawing;

# %%
g = gt_load('../notebooks/Wiki-Rfa.net.gz')
m = gt_draw.sfdp_layout(g)
gt_move(g, m)
gt_save(g, 'Wiki-Rfa.net.gz')
r=netpixi.render('Wiki-Rfa.net.gz',infinite=True);
# Out:
#         <div id="gCDagsxJuhJ9uGDFyyHwRj"></div>
#         <script>netpixi.render('gCDagsxJuhJ9uGDFyyHwRj', 'Wiki-Rfa.net.gz', 1.7777777777777777, true, true, false);</script>

# %% [markdown]
# #### Propriedades e tipos

# %%
netpixi.peek('../notebooks/Wiki-Rfa.net.gz')
# Out:
# GRAPH
#     Unknown: int
#     Siva1979: int
#     Mailer diablo: int
#     Merovingian: int
#     Wizardman: int
#     Acalamari: int
#     Xoloz: int
#     Pedro: int
#     Dlohcierekim: int
#     Bearian: int
#     Stifle: int
#     Jmlk17: int
#     MONGO: int
#     Terence Ong: int
#     Malinaccier: int
#     Wisdom89: int
#     Newyorkbrad: int
#     Axl: int
#     Casliber: int
#     Rogerd: int
#     Pharaoh of the Wizards: int
#     Majorly: int
#     Juliancolton: int
#     (aeropagitica): int
#     GlassCobra: int
#     Lankiveil: int
#     Fastily: int
#     Sjakkalle: int
#     Anas Salloum: int
#     Jayjg: int
#     Rudget: int
#     Captain panda: int
#     Blnguyen: int
#     danntm: int
#     Nishkid64: int
#     Husond: int
#     Bhadani: int
#     Jaranda: int
#     Daniel: int
#     WereSpielChequers: int
#     Sharkface217: int
#     Radiant!: int
#     Mike 7: int
#     Ktr101: int
#     Andrevan: int
#     El C: int
#     Jusjih: int
#     Jonathunder: int
#     America69: int
#     WJBscribe: int
#     Rje: int
#     NHRHS2010: int
#     Proto: int
#     Addhoc: int
#     Bibliomaniac15: int
#     SlimVirgin: int
#     DGG: int
#     RyanGerbil10: int
#     Useight: int
#     JIP: int
#     Keepscases: int
#     Aranda56: int
#     Christopher Parham: int
#     Majoreditor: int
#     Jahiegel: int
#     Sarah Ewart: int
#     DarthVader: int
#     SoWhy: int
#     Tawker: int
#     Journalist: int
#     PhilKnight: int
#     Cirt: int
#     Crzrussian: int
#     Boing! said Zebedee: int
#     Davewild: int
#     JoshuaZ: int
#     FireFox: int
#     King of Hearts: int
#     Anonymous Dissident: int
#     NSLE: int
#     Cometstyles: int
#     Ryan Postlethwaite: int
#     Lradrama: int
#     Moe Epsilon: int
#     Grutness: int
#     Antandrus: int
#     FayssalF: int
#     Fetchcomms: int
#     Tiptoety: int
#     Naconkantari: int
#     Spencer: int
#     Keeper76: int
#     BD2412: int
#     PeaceNT: int
#     Tanthalas39: int
#     Master&Expert: int
#     Khoikhoi: int
#     Lst27: int
#     Ageo020: int
#     Rama's Arrow: int
#     Ceranthor: int
#     Riana: int
#     Neil: int
#     Ral315: int
#     Michael Snow: int
#     Juntung: int
#     Master of Puppets: int
#     Alex Bakharev: int
#     Anthony.bradbury: int
#     Grue: int
#     Richardcavell: int
#     Nihonjoe: int
#     RP459: int
#     The Rambling Man: int
#     Secret: int
#     Everyking: int
#     Airplaneman: int
#     Dank: int
#     MBisanz: int
#     Balloonman: int
#     hmwith: int
#     Mazca: int
#     Titoxd: int
#     Dihydrogen Monoxide: int
#     Ultraexactzz: int
#     A Nobody: int
#     DS1953: int
#     NuclearWarfare: int
#     Epbr123: int
#     Lar: int
#     DarkFalls: int
#     Kungfuadam: int
#     Phaedriel: int
#     JodyB: int
#     Alison: int
#     Little Mountain 5: int
#     Carlossuarez46: int
#     Iridescent: int
#     Royboycrashfan: int
#     Trusilver: int
#     RegentsPark: int
#     Modernist: int
#     Master Jay: int
#     Ironholds: int
#     Utcursch: int
#     Kirill Lokshin: int
#     Starblind: int
#     Giants27: int
#     ArcAngel: int
#     Cyclonenim: int
#     John254: int
#     A. B.: int
#     Hiberniantears: int
#     Stephen: int
#     Ret.Prof: int
#     Sceptre: int
#     AGK: int
#     Pascal.Tesson: int
#     Samir (The Scope): int
#     Rory096: int
#     Kudpung: int
#     Quarl: int
#     Minimac: int
#     Townlake: int
#     Neutrality: int
#     James086: int
#     Mkativerata: int
#     LessHeard vanU: int
#     Kusma: int
#     Ugen64: int
#     HJ Mitchell: int
#     172: int
#     Ecoleetage: int
#     Grandmasterka: int
#     WBOSITG: int
#     Atama: int
#     Searchme: int
#     AldeBaer: int
#     Kingturtle: int
#     Garion96: int
#     JayHenry: int
#     Yanksox: int
#     Miranda: int
#     Jusdafax: int
#     Slgrandson: int
#     Gwernol: int
#     Zaxem: int
#     Tryptofish: int
#     Nick: int
#     Zzyzx11: int
#     Andypandy.UK: int
#     Private Butcher: int
#     Angusmclellan: int
#     Computerjoe: int
#     Darwinek: int
#     Guettarda: int
#     Kmweber: int
#     OlEnglish: int
#     Neurolysis: int
#     BuickCenturyDriver: int
#     Prodego: int
#     Walton monarchist89: int
#     Hokeman: int
#     EdJohnston: int
#     Moreschi: int
#     MC10: int
#     John: int
#     Swatjester: int
#     OhanaUnited: int
#     Chacor: int
#     Avraham: int
#     W.marsh: int
#     T-rex: int
#     Shadowjams: int
#     Timmeh: int
#     Sir Nicholas de Mimsy-Porpington: int
#     Agent 86: int
#     Soap: int
#     Ottawa4ever: int
#     Hoopydink: int
#     Jj137: int
#     Doc glasgow: int
#     Wiki alf: int
#     Splash: int
#     Naerii: int
#     Anonymous editor: int
#     Dweller: int
#     Redwolf24: int
#     Shreshth91: int
#     GHe: int
#     Amarkov: int
#     Le Grand Roi des Citrouilles: int
#     FeydHuxtable: int
#     Politics rule: int
#     Sango123: int
#     Malleus Fatuorum: int
#     Garden: int
#     Bishonen: int
#     Wehwalt: int
#     VanTucky: int
#     Caspian blue: int
#     Alkivar: int
#     KojiDude: int
#     Phantomsteve: int
#     Alphachimp: int
#     Pastor Theo: int
#     YechielMan: int
#     Espresso Addict: int
#     Xaosflux: int
#     Sandstein: int
#     The Transhumanist: int
#     Elkman: int
#     Graeme Bartlett: int
#     Masssiveego: int
#     CharlotteWebb: int
#     DaGizza: int
#     Dorftrottel: int
#     Frank: int
#     SilkTork: int
#     Pschemp: int
#     MPerel: int
#     Mindspillage: int
#     Kimchi.sg: int
#     Geogre: int
#     Bucketsofg: int
#     RayAYang: int
#     Mackensen: int
#     Jossi: int
#     The Random Editor: int
#     Sj: int
#     the wub: int
#     Kbdank71: int
#     Terenceong1992: int
#     NSD: int
#     Yuser31415: int
#     Athaenara: int
#     Jwrosenzweig: int
#     Trialsanderrors: int
#     Nightstallion: int
#     Walton One: int
#     AdjustShift: int
#     Kingboyk: int
#     Keegan: int
#     Bluemoose: int
#     Friday: int
#     Francs2000: int
#     Jreferee: int
#     Jclemens: int
#     Cyberjunkie: int
#     Dfrg.msc: int
#     Reyk: int
#     Philippe: int
#     RN: int
#     Kelly Martin: int
#     Encyclopedist: int
#     Ambi: int
#     Bratsche: int
#     Reaper Eternal: int
#     celestianpower: int
#     Terence: int
#     Tinucherian: int
#     Deb: int
#     Salvio giuliano: int
#     Danny: int
#     DakotaKahn: int
#     Sarah: int
#     David Gerard: int
#     Protonk: int
#     Dlyons493: int
#     Shalom: int
#     Blankfaze: int
#     EJF: int
#     Marlith: int
#     IMatthew: int
#     Boothy443: int
#     RadioKirk: int
#     Cameron: int
#     Ged UK: int
#     Swarm: int
#     S Marshall: int
#     PeterSymonds: int
#     Steven Walling: int
#     David Fuchs: int
#     Eluchil404: int
#     Hiding: int
#     SWik78: int
#     SJP: int
#     Hobit: int
#     Hipocrite: int
#     Themindset: int
#     Download: int
#     east718: int
#     Matt Yeager: int
#     Spartaz: int
#     Hello32020: int
#     Plutonium27: int
#     Hall Monitor: int
#     Courcelles: int
#     Ajraddatz: int
#     X!: int
#     Deckiller: int
#     Ched Davis: int
#     Nsk92: int
#     Rspeer: int
#     Deathphoenix: int
#     Rx StrangeLove: int
#     Realist2: int
#     Freestylefrappe: int
#     Voice of All: int
#     Srikeit: int
#     Themfromspace: int
#     MuZemike: int
#     Dank55: int
#     TigerShark: int
#     Tone: int
#     CambridgeBayWeather: int
#     Seraphimblade: int
#     Cyde: int
#     Ottava Rima: int
#     28bytes: int
#     Deiz: int
#     Brookie: int
#     Deskana: int
#     Kiefer.Wolfowitz: int
#     Haukurth: int
#     Viridae: int
#     LaraLove: int
#     Brian0918: int
#     Mikhailov Kusserow: int
#     SandyGeorgia: int
#     Christopherparham: int
#     Gator1: int
#     Doc Quintana: int
#     SynergeticMaggot: int
#     Scarian: int
#     MarkGallagher: int
#     Asenine: int
#     MatthewFenton: int
#     Icewedge: int
#     Sean Black: int
#     Slowking Man: int
#     Orderinchaos: int
#     Robofish: int
#     Flcelloguy: int
#     Rodhullandemu: int
#     KillerChihuahua: int
#     Daniel.Bryant: int
#     Slf67: int
#     AniMate: int
#     Joturner: int
#     Hirohisat: int
#     Oleg Alexandrov: int
#     Kraftlos: int
#     Royalbroil: int
#     Jorcoga: int
#     Grunt: int
#     Cbrown1023: int
#     Avruch: int
#     Black Kite: int
#     Can't sleep, clown will eat me: int
#     Dionyseus: int
#     Johnbod: int
#     Joe Decker: int
#     FlyingToaster: int
#     Pgk: int
#     Robchurch: int
#     Bejinhan: int
#     Jfdwolff: int
#     RMHED: int
#     Kicking222: int
#     Deville: int
#     Mirv: int
#     iMatthew: int
#     Nichalp: int
#     Spebi: int
#     Jaxl: int
#     Pete.Hurd: int
#     White Shadows: int
#     Mr. Lefty: int
#     FloNight: int
#     J-stan: int
#     BigDT: int
#     Orfen: int
#     Dylan620: int
#     JzG: int
#     Ugur Basak: int
#     JamieS93: int
#     Tyrenius: int
#     TUF-KAT: int
#     Mr.Z-man: int
#     Alhutch: int
#     Ganfon: int
#     Coredesat: int
#     DragonflySixtyseven: int
#     The undertow: int
#     Shapiros10: int
#     Junglecat: int
#     Jni: int
#     Phgao: int
#     TantalumTelluride: int
#     Masterpiece2000: int
#     TenOfAllTrades: int
#     Banes: int
#     SQL: int
#     Gurch: int
#     Carbonite: int
#     Guinnog: int
#     Orangemarlin: int
#     Opabinia regalis: int
#     Angela: int
#     Snowolf: int
#     aitias: int
#     Black Falcon: int
#     Colonel Warden: int
#     Razorflame: int
#     Dbiv: int
#     SarekOfVulcan: int
#     RandyWang: int
#     NoSeptember: int
#     Zeibura: int
#     Malinaccier Public: int
#     Mets501: int
#     Tony Sidaway: int
#     Sven Manguard: int
#     Aqwis: int
#     Editorofthewiki: int
#     Karmafist: int
#     Shereth: int
#     Insanephantom: int
#     Infrangible: int
#     Arkyan: int
#     Taxman: int
#     Aiken drum: int
#     Fire Star: int
#     Mike Halterman: int
#     Grace Note: int
#     Carrite: int
#     KnowledgeOfSelf: int
#     Xenocidic: int
#     Carlosguitar: int
#     Steel359: int
#     Wifione: int
#     Marskell: int
#     the ed17: int
#     Pmlinediter: int
#     Heimstern: int
#     Jehochman: int
#     Mizu onna sango15: int
#     DiverseMentality: int
#     Sumoeagle179: int
#     Cynical: int
#     teh tennisman: int
#     Paul Erik: int
#     Thryduulf: int
#     Shawn in Montreal: int
#     Coemgenus: int
#     Jauerback: int
#     Dinosaur puppy: int
#     Dbachmann: int
#     J.delanoy: int
#     My76Strat: int
#     Doug Bell: int
#     JetLover: int
#     Mschel: int
#     Erik the Red 2: int
#     Nick mallory: int
#     DeadBot: int
#     Rhymeless: int
#     Drmies: int
#     EVula: int
#     ChildofMidnight: int
#     Anárion: int
#     Alex9891: int
#     Encephalon: int
#     Nephron: int
#     Rlevse: int
#     SushiGeek: int
#     Meelar: int
#     Dureo: int
#     GDonato: int
#     Dmcdevit: int
#     Krimpet: int
#     Unionhawk: int
#     Pdcook: int
#     Beeblebrox: int
#     Aaroncrick: int
#     Agathoclea: int
#     Duk: int
#     AtheWeatherman: int
#     Kukini: int
#     R.D.H. (Ghost In The Machine): int
#     Wile E. Heresiarch: int
#     Netoholic: int
#     Aguerriero: int
#     Izehar: int
#     Chzz: int
#     Foxy Loxy: int
#     Phoenix2: int
#     Explicit: int
#     BryanG: int
#     Digitalme: int
#     VirtualSteve: int
#     Valley2city: int
#     Wikihermit: int
#     Linuxbeak: int
#     Chaser: int
#     Cribcage: int
#     Gadfium: int
#     Feydey: int
#     Kim Bruning: int
#     Kefalonia: int
#     Scimitar: int
#     Animum: int
#     A Stop at Willoughby: int
#     Maxim: int
#     Nae'blis: int
#     Polargeo: int
#     Dreadstar: int
#     Buchanan-Hermit: int
#     Denelson83: int
#     Mlpearc: int
#     Haza-w: int
#     Lostintherush: int
#     Sir james paul: int
#     ForestH2: int
#     Shoessss: int
#     Y: int
#     Mjal: int
#     Hi878: int
#     WFCforLife: int
#     Acetic Acid: int
#     Peridon: int
#     Natl1: int
#     TimVickers: int
#     SorryGuy: int
#     Ghirlandajo: int
#     Cube lurker: int
#     Inka 888: int
#     HighwayCello: int
#     Wezzo: int
#     John Reaves: int
#     Giggy: int
#     Sd31415: int
#     Thumbelina: int
#     Tim Song: int
#     Melsaran: int
#     Sn0wflake: int
#     Essjay: int
#     PedanticallySpeaking: int
#     Aldux: int
#     Pavel Vozenilek: int
#     Bwilkins: int
#     Bubba hotep: int
#     Rschen7754: int
#     ST47: int
#     VegaDark: int
#     Keilana: int
#     Arjun01: int
#     Drini: int
#     Begoon: int
#     Rockpocket: int
#     Dennis Brown: int
#     Alex43223: int
#     CryptoDerk: int
#     Boricuaeddie: int
#     B: int
#     Lemonflash: int
#     Roux: int
#     Matthew: int
#     Backslash Forwardslash: int
#     Epeefleche: int
#     Deacon of Pndapetzim: int
#     KrakatoaKatie: int
#     Faithlessthewonderboy: int
#     BorgHunter: int
#     N5iln: int
#     Mel Etitis: int
#     RickK: int
#     JCarriker: int
#     Lucky 6.9: int
#     Firsfron: int
#     Worm That Turned: int
#     Connormah: int
#     TheCustomOfLife: int
#     Silensor: int
#     BaseballBaby: int
#     GregAsche: int
#     Timotheus Canens: int
#     1ne: int
#     Laurinavicius: int
#     Rjd0060: int
#     riana dzasta: int
#     Chick Bowen: int
#     Wikidudeman: int
#     Sphilbrick: int
#     Kubigula: int
#     Bradjamesbrown: int
#     Kncyu38: int
#     Thunderbrand: int
#     Irpen: int
#     Fang Aili: int
#     ESkog: int
#     Looper5920: int
#     Ixfd64: int
#     Coffee: int
#     Rebelguys2: int
#     Coren: int
#     TParis: int
#     Aditya: int
#     Alphax: int
#     Fabrictramp: int
#     Dario vet: int
#     Taelus: int
#     Amorymeltzer: int
#     The Halo: int
#     Youngamerican: int
#     Shell Kinney: int
#     Dustihowe: int
#     Rettetast: int
#     Warofdreams: int
#     Icestorm815: int
#     -Midorihana-: int
#     The ed17: int
#     Briangotts: int
#     EWS23: int
#     Jossifresco: int
#     Snottywong: int
#     Aksi great: int
#     Gordonrox24: int
#     Twooars: int
#     Ronhjones: int
#     Res2216firestar: int
#     Orphan Wiki: int
#     One: int
#     Mike1: int
#     Wisden17: int
#     Alai: int
#     Jafeluv: int
#     OwenX: int
#     MastCell: int
#     TruthCrusader: int
#     Stwalkerster: int
#     Heligoland: int
#     Decltype: int
#     The Blade of the Northern Lights: int
#     Dekimasu: int
#     AuburnPilot: int
#     GB fan: int
#     Riana dzasta: int
#     Samir: int
#     Bobrayner: int
#     Off2riorob: int
#     Carioca: int
#     Marine 69-71: int
#     Tofutwitch11: int
#     BanyanTree: int
#     AlexandrDmitri: int
#     Seicer: int
#     Phoenix-wiki: int
#     SWAdair: int
#     Wikipediarules2221: int
#     Cosmic Latte: int
#     Nousernamesleft: int
#     Hoary: int
#     Hamster Sandwich: int
#     Candlewicke: int
#     Khukri: int
#     Dwaipayanc: int
#     Redvers: int
#     The wub: int
#     Warrah: int
#     Spike Wilbury: int
#     Johnleemk: int
#     GiantSnowman: int
#     Adambiswanger1: int
#     Davidcannon: int
#     MacGyverMagic: int
#     Just H: int
#     Aitias: int
#     TreasuryTag: int
#     Williamborg: int
#     Jebus989: int
#     Moonriddengirl: int
#     Sephiroth BCR: int
#     Cool Hand Luke: int
#     December21st2012Freak: int
#     Ncmvocalist: int
#     Qst: int
#     SUIT: int
#     Camaron: int
#     After Midnight: int
#     Will Beback: int
#     Shappy: int
#     South Bay: int
#     Jersey Devil: int
#     Jake Wartenberg: int
#     Coldplay Expert: int
#     PS2pcGAMER: int
#     MichaelQSchmidt: int
#     Longhair: int
#     Jkelly: int
#     Texture: int
#     Brewcrewer: int
#     Ceoil: int
#     Func: int
#     Chamal N: int
#     Android79: int
#     Jc37: int
#     Chrislk02: int
#     Vodello: int
#     Tommy2010: int
#     Smithers7: int
#     AndonicO: int
#     Synergy: int
#     Carnildo: int
#     PookeyMaster: int
#     TeckWiz: int
#     SheffieldSteel: int
#     Gaillimh: int
#     Celestianpower: int
#     Michaelas10: int
#     Mushroom: int
#     Anonymous anonymous: int
#     Winhunter: int
#     Latinus: int
#     giggy: int
#     Katalaveno: int
#     Daniel5127: int
#     Tombomp: int
#     Gtstricky: int
#     Spawn Man: int
#     WillMak050389: int
#     Ponyo: int
#     Jack: int
#     AutomaticStrikeout: int
#     Rdsmith4: int
#     Raul654: int
#     Gidonb: int
#     Picaroon9288: int
#     Ronnotel: int
#     Skinwalker: int
#     Nakon: int
#     WilyD: int
#     Cremepuff222: int
#     Stanistani: int
#     Isomorphic: int
#     The Utahraptor: int
#     JYolkowski: int
#     Wsiegmund: int
#     Jiang: int
#     Quadell: int
#     Black Harry: int
#     Natalya: int
#     Mariano Anto Bruno Mascarenhas: int
#     Strange Passerby: int
#     Petros471: int
#     Astrotrain: int
#     Jtkiefer: int
#     Jengod: int
#     Shirik: int
#     Monty845: int
#     Chris 73: int
#     Exir Kamalabadi: int
#     Guerillero: int
#     Bcorr: int
#     Cecropia: int
#     NativeForeigner: int
#     KHM03: int
#     Dean B: int
#     Rootology: int
#     Knowledge Seeker: int
#     Shyam Bihari: int
#     Malleus Fatuarum: int
#     AO: int
#     Bobet: int
#     Pilotguy: int
#     Xiner: int
#     7: int
#     Bart133: int
#     Diligent Terrier: int
#     Herbythyme: int
#     Thingg: int
#     Covington: int
#     Johntex: int
#     Ifnord: int
#     Raven4x4x: int
#     MBK004: int
#     DougsTech: int
#     IronGargoyle: int
#     Ragesoss: int
#     Macy: int
#     Tree Biting Conspiracy: int
#     Syrthiss: int
#     The High Fin Sperm Whale: int
#     Durin: int
#     Queerbubbles: int
#     Deliriousandlost: int
#     Hughcharlesparker: int
#     Everyme: int
#     Tyrol5: int
#     Orlady: int
#     Lord Roem: int
#     The Sunshine Man: int
#     Bkonrad: int
#     FeloniousMonk: int
#     HappyCamper: int
#     Ezhiki: int
#     Eusebeus: int
#     Xymmax: int
#     Dgies: int
#     Phroziac: int
#     TShilo12: int
#     Hahnchen: int
#     BigDom: int
#     Alan Au: int
#     Tikiwont: int
#     Kim Dent-Brown: int
#     MrPrada: int
#     Stewartadcock: int
#     Bwrs: int
#     Euryalus: int
#     Cuivienen: int
#     Hdt83: int
#     FreplySpang: int
#     GeneralPatton: int
#     Bencherlite: int
#     Kilo-Lima: int
#     Gryffindor: int
#     Jeffrey O. Gustafson: int
#     Steven Zhang: int
#     Ambuj.Saxena: int
#     Ohnoitsjamie: int
#     Ozgod: int
#     PrestonH: int
#     Badger Drink: int
#     Ta bu shi da yu: int
#     Tewfik: int
#     Wimt: int
#     Vilerage: int
#     Toddst1: int
#     Patar knight: int
#     Benon: int
#     avriette: int
#     MaxSem: int
#     Steve Crossin: int
#     Xdenizen: int
#     Sr13: int
#     JForget: int
#     Wayne Slam: int
#     Durova: int
#     UninvitedCompany: int
#     LAAFan: int
#     Someguy1221: int
#     Idont havaname: int
#     Anthony Bradbury: int
#     Triona: int
#     G1ggy: int
#     Sandahl: int
#     Metamagician3000: int
#     tomf688: int
#     Hcheney: int
#     DARTH SIDIOUS 2: int
#     Hephaestos: int
#     Renesis13: int
#     Risker: int
#     Anger22: int
#     Sparklism: int
#     Stephen B Streater: int
#     Thehelpfulone: int
#     Acegikmo1: int
#     Shanel: int
#     Afonso Silva: int
#     DVD R W: int
#     Lectonar: int
#     Anirudhsbh: int
#     Aaron: int
#     Mr Senseless: int
#     Haemo: int
#     AlexiusHoratius: int
#     IronDuke: int
#     Caulde: int
#     Perfect Proposal: int
#     Tony1: int
#     SluggoOne: int
#     Kscottbailey: int
#     Benjiboi: int
#     Physicq210: int
#     Skomorokh: int
#     RGTraynor: int
#     Tariqabjotu: int
#     Leaky caldron: int
#     Springeragh: int
#     Tintin1107: int
#     Jitse Niesen: int
#     Bennyboyz3000: int
#     Milk's Favorite Cookie: int
#     U.S.A.U.S.A.U.S.A.: int
#     Kafziel: int
#     Misza13: int
#     Alabamaboy: int
#     Cocytus: int
#     Mifter: int
#     Harro5: int
#     Fattyjwoods: int
#     Stormie: int
#     Craftyminion: int
#     Gogo Dodo: int
#     Dragons flight: int
#     Plastikspork: int
#     Pigman: int
#     Banime: int
#     Pmanderson: int
#     JoJo: int
#     Admrboltz: int
#     Mangojuice: int
#     KTC: int
#     TCO: int
#     Bduke: int
#     J Milburn: int
#     Kuru: int
#     Strikerforce: int
#     Colin Kimbrell: int
#     Jennavecia: int
#     Lenticel: int
#     Seadog.M.S: int
#     Pol430: int
#     Isotope23: int
#     Steveo2: int
#     JamesTeterenko: int
#     Anetode: int
#     Jedi6: int
#     Agüeybaná: int
#     Meegs: int
#     Jobe6: int
#     Gurubrahma: int
#     Danaman5: int
#     Hahc21: int
#     Go Phightins!: int
#     Mattinbgn: int
#     TheKMan: int
#     Sarge Baldy: int
#     Gnangarra: int
#     Diego Grez: int
#     Srose: int
#     Dwayne: int
#     Eagle 101: int
#     Mr. Stradivarius: int
#     John Reid: int
#     YellowMonkey: int
#     Pichpich: int
#     Baseball Watcher: int
#     delldot: int
#     Fox: int
#     Roger Davies: int
#     Gazimoff: int
#     Mabdul: int
#     Sam Spade: int
#     Runcorn: int
#     SqueakBox: int
#     Theleftorium: int
#     Musical Linguist: int
#     Chairboy: int
#     Bastique: int
#     Real96: int
#     Lahiru k: int
#     Future Perfect at Sunrise: int
#     Nyttend: int
#     RyanCross: int
#     JoanneB: int
#     Abce2: int
#     Tijuana Brass: int
#     Singopo: int
#     Triplestop: int
#     ErikTheBikeMan: int
#     CanadianCaesar: int
#     Anwar saadat: int
#     Paul Pigman: int
#     Zsinj: int
#     ItsZippy: int
#     Kurtis: int
#     jonny-mt: int
#     Tangotango: int
#     Hedley: int
#     @pple: int
#     Staxringold: int
#     HiDrNick: int
#     Shizane: int
#     Achowat: int
#     V. Molotov: int
#     JHMM13: int
#     Morven: int
#     Dar-Ape: int
#     Belovedfreak: int
#     Guanaco: int
#     Shirahadasha: int
#     BlankVerse: int
#     SCZenz: int
#     Bluerasberry: int
#     MLA: int
#     Nolelover: int
#     Valtoras: int
#     Snowspinner: int
#     Zoe: int
#     Samsara: int
#     Tavix: int
#     Gigs: int
#     Badlydrawnjeff: int
#     harej: int
#     TomasBat: int
#     Scottywong: int
#     PJM: int
#     Werdna648: int
#     Llama man: int
#     Conscious: int
#     Kalathalan: int
#     RockMFR: int
#     Djsasso: int
#     Evilclown93: int
#     Pepsidrinka: int
#     Seresin: int
#     NeoFreak: int
#     Monterey Bay: int
#     Chazz88: int
#     Ilyanep: int
#     Teke: int
#     Lord Voldemort: int
#     Nancy: int
#     Jjjsixsix: int
#     Until It Sleeps: int
#     Chetblong: int
#     Marek69: int
#     Dmn: int
#     George The Dragon: int
#     Scientizzle: int
#     XDanielx: int
#     Tony Fox: int
#     Tellyaddict: int
#     AmiDaniel: int
#     Redux: int
#     Doczilla: int
#     NormanEinstein: int
#     Cactus.man: int
#     Mr. IP: int
#     Cyberpower678: int
#     Yamaguchi先生: int
#     NVO: int
#     DerHexer: int
#     Lightdarkness: int
#     Ingoolemo: int
#     RockManQ: int
#     Patman2648: int
#     Maximillion Pegasus: int
#     Daveydweeb: int
#     gadfium: int
#     Harlowraman: int
#     Jim62sch: int
#     CFIF: int
#     Angr: int
#     Gaff: int
#     Ffirehorse: int
#     Folantin: int
#     Martinp: int
#     Eagles247: int
#     Morning Sunshine: int
#     AQu01rius: int
#     Arnzy: int
#     Logan: int
#     MichaelBillington: int
#     Mostly Rainy: int
#     Ryan Vesey: int
#     Argyriou: int
#     Nihiltres: int
#     Ck lostsword: int
#     The Minister of War: int
#     Woody: int
#     Locke Cole: int
#     Andromedabluesphere440: int
#     Pumpmeup: int
#     Squash: int
#     GRBerry: int
#     TTTSNB: int
#     Maser Fletcher: int
#     Shanes: int
#     Torreslfchero: int
#     Nikkimaria: int
#     Buggie111: int
#     Armbrust: int
#     Abeg92: int
#     Ling.Nut: int
#     Camaron1: int
#     Tide rolls: int
#     Y0u: int
#     GeorgeMoney: int
#     William M. Connolley: int
#     Olorin28: int
#     Petaholmes: int
#     Martinp23: int
#     Iterator12n: int
#     Speed CG: int
#     Essexmutant: int
#     WikiFanatic: int
#     Savidan: int
#     Daniel Case: int
#     Abecedare: int
#     MarmadukePercy: int
#     EyeSerene: int
#     Intothatdarkness: int
#     Addshore: int
#     gwernol: int
#     Harland1: int
#     Rjanag: int
#     Gilderien: int
#     Mark: int
#     Secretlondon: int
#     Jacoplane: int
#     TomStar81: int
#     Burner0718: int
#     Elaragirl: int
#     Nobleeagle: int
#     SchmuckyTheCat: int
#     SunCreator: int
#     RC-0722: int
#     Darthgriz98: int
#     Mmounties: int
#     Shimgray: int
#     Knucmo2: int
#     Mentifisto: int
#     Persian Poet Gal: int
#     Alexfusco5: int
#     It Is Me Here: int
#     Ludraman: int
#     Hadal: int
#     J.smith: int
#     Johann Wolfgang: int
#     xeno: int
#     Gfoley4: int
#     ABF: int
#     wiooiw: int
#     TBC: int
#     Bornhj: int
#     Bunchofgrapes: int
#     Hut 8.5: int
#     Miborovsky: int
#     UkPaolo: int
#     Malber: int
#     Kralizec!: int
#     Elen of the Roads: int
#     Ben MacDui: int
#     Mcginnly: int
#     Hersfold: int
#     Scetoaux: int
#     O: int
#     Miniapolis: int
#     Tiddly Tom: int
#     Fennec: int
#     ThaddeusB: int
#     Jguk: int
#     Dreamafter: int
#     Jdforrester: int
#     Tinkleheimer: int
#     Jamesontai: int
#     Sunderland06: int
#     Short Brigade Harvester Boris: int
#     Yamamoto Ichiro: int
#     Theresa knott: int
#     FCYTravis: int
#     Jondel: int
#     GIen: int
#     ILovePlankton: int
#     Vishnava: int
#     Borisblue: int
#     Kchase02: int
#     Derex: int
#     TenPoundHammer: int
#     Bakasuprman: int
#     Atmoz: int
#     Ikiroid: int
#     Deli nk: int
#     Nick-D: int
#     WODUP: int
#     Bjweeks: int
#     Cool3: int
#     The JPS: int
#     Twenty Years: int
#     Casmith 789: int
#     Lawrence Cohen: int
#     Esteffect: int
#     Christopher Sundita: int
#     Gutworth: int
#     CJLL Wright: int
#     Pohta ce-am pohtit: int
#     Kanonkas: int
#     Pepper: int
#     Jcam: int
#     Collect: int
#     PrincessofLlyr: int
#     Tnxman307: int
#     Cindamuse: int
#     Neutralhomer: int
#     GabeMc: int
#     Maedin: int
#     Gromlakh: int
#     Basket of Puppies: int
#     Tom harrison: int
#     Ombudsman: int
#     Gzornenplatz: int
#     Cla68: int
#     Zscout370: int
#     crazytales56297: int
#     Stubbleboy: int
#     Spangineer: int
#     ErikHaugen: int
#     Sonia: int
#     Menchi: int
#     Camaeron: int
#     Howcheng: int
#     Maximus Rex: int
#     Gmaxwell: int
#     Kylu: int
#     Canadian-Bacon: int
#     Mike Christie: int
#     Banana04131: int
#     Gonzonoir: int
#     ElinorD: int
#     Moondyne: int
#     Weatherman90: int
#     Nomader: int
#     Blue520: int
#     Bedford: int
#     RedWordSmith: int
#     Oldelpaso: int
#     Dendodge: int
#     TacoDeposit: int
#     Irbisgreif: int
#     TravisTX: int
#     S. Dean Jameson: int
#     Semperf: int
#     Evilphoenix: int
#     Carcharoth: int
#     AubreyEllenShomo: int
#     Ashibaka: int
#     Patton123: int
#     Goldom: int
#     Szyslak: int
#     Ram-Man: int
#     Tom Morris: int
#     Peripitus: int
#     Urshyam: int
#     TKD: int
#     Accounting4Taste: int
#     Rocksanddirt: int
#     Rcsprinter123: int
#     Quartermaster: int
#     Ruhrfisch: int
#     Barneca: int
#     Kaaveh Ahangar: int
#     ImperatorExercitus: int
#     MJ94: int
#     Alpha Quadrant: int
#     henrik: int
#     AudeVivere: int
#     Mathwiz2020: int
#     Crum375: int
#     Awyong Jeffrey Mordecai Salleh: int
#     Bsimmons666: int
#     Yandman: int
#     ProhibitOnions: int
#     David D.: int
#     Carrp: int
#     Glrx: int
#     Hydnjo: int
#     wknight94: int
#     Legoktm: int
#     Jersyko: int
#     Mark Dingemanse: int
#     IShadowed: int
#     Law: int
#     Kierzek: int
#     Mhking: int
#     Alzarian16: int
#     Onthost: int
#     Woohookitty: int
#     The Land: int
#     MarcoTolo: int
#     Ed Poor: int
#     The Bread: int
#     The Interior: int
#     Xp54321: int
#     PGWG: int
#     SashaNein: int
#     Pedant: int
#     Spongefrog: int
#     Lethe: int
#     Bfigura: int
#     Chris G: int
#     CapitalR: int
#     Looie496: int
#     Sarcasticidealist: int
#     Mo0: int
#     Ligulem: int
#     Cryptic: int
#     Rami R: int
#     Voice of All(MTG): int
#     Mark Arsten: int
#     Who: int
#     Sean William: int
#     P.B. Pilhet: int
#     Robdurbar: int
#     RFerreira: int
#     A Train: int
#     Kablammo: int
#     Slon02: int
#     John Carter: int
#     Fadix: int
#     BrownHairedGirl: int
#     GrazingshipIV: int
#     Flowerparty: int
#     SchfiftyThree: int
#     Trebor Rowntree: int
#     Gray Porpoise: int
#     Krator: int
#     GT5162: int
#     Edivorce: int
#     Cowman109: int
#     Pgallert: int
#     Piotrus: int
#     Xyrael: int
#     Croat Canuck: int
#     Sasha Callahan: int
#     Joy Stovall: int
#     Kingpin13: int
#     JJay: int
#     Gkhan: int
#     Shauri: int
#     Fences and windows: int
#     Enochlau: int
#     ryanpostlethwaite: int
#     BusterD: int
#     SmokeyJoe: int
#     American Eagle: int
#     CBDunkerson: int
#     Biekko: int
#     How do you turn this on: int
#     Darkspots: int
#     Messedrocker: int
#     Valentinian: int
#     pschemp: int
#     KI: int
#     Whouk: int
#     Curt Wilhelm VonSavage: int
#     NASCAR Fan24: int
#     Gonzo fan2007: int
#     Tuspm: int
#     Go for it!: int
#     Nauticashades: int
#     K50 Dude: int
#     Leebo: int
#     Mattisse: int
#     Geni: int
#     Ulayiti: int
#     Thine Antique Pen: int
#     Sunray: int
#     LordViD: int
#     Sasquatch: int
#     Cool Blue: int
#     Neranei: int
#     Calton: int
#     Horologium: int
#     Xnuala: int
#     Yuckfoo: int
#     Paolo Liberatore: int
#     Ankit Maity: int
#     Hullaballoo Wolfowitz: int
#     Leujohn: int
#     Truco: int
#     Filelakeshoe: int
#     ShaneKing: int
#     Tempodivalse: int
#     Pilif12p: int
#     Jasper Deng: int
#     Bbatsell: int
#     Gracenotes: int
#     Wooyi: int
#     Access Denied: int
#     Dan100: int
#     Chmod007: int
#     Georgewilliamherbert: int
#     Humus sapiens: int
#     WriterListener: int
#     John Kenney: int
#     Mecu: int
#     Tragic Baboon: int
#     Sole Soul: int
#     MER-C: int
#     Goodmorningworld: int
#     MSGJ: int
#     Martin Osterman: int
#     TBrandley: int
#     Ealdgyth: int
#     ArielGold: int
#     Aude: int
#     Dru of Id: int
#     Elf-friend: int
#     Finlay McWalter: int
#     HighInBC: int
#     SpacemanSpiff: int
#     Brisvegas: int
#     Flewis: int
#     Lothar von Richthofen: int
#     Lantoka: int
#     ^demon: int
#     Trilobite: int
#     Rebecca: int
#     Assasin Joe: int
#     Kwsn: int
#     Dori: int
#     Ganeshk: int
#     Derild4921: int
#     Richardshusr: int
#     Lazulilasher: int
#     Olaf Davis: int
#     Akhilleus: int
#     TonyTheTiger: int
#     Charles Matthews: int
#     RyRy5: int
#     Mysekurity: int
#     Philosopher: int
#     Kathryn NicDhàna: int
#     R: int
#     Camw: int
#     Edgar181: int
#     Gwynand: int
#     Jujutacular: int
#     Mustafa Akalp: int
#     Orthogonal: int
#     SebastianHelm: int
#     Jenks24: int
#     Juppiter: int
#     Niyant: int
#     Mjroots: int
#     A.Z.: int
#     Calmer Waters: int
#     JPG-GR: int
#     ThinkBlue: int
#     Jareth: int
#     Seivad: int
#     Gears of War: int
#     Jbamb: int
#     Austin Hair: int
#     DeltaQuad: int
#     Enigmaman: int
#     Decumanus: int
#     Katerenka: int
#     RadicalBender: int
#     Crotchety Old Man: int
#     TFOWR: int
#     Immunize: int
#     Jayvdb: int
#     Wenli: int
#     Winger84: int
#     Canderson7: int
#     Basketball110: int
#     Inks.LWC: int
#     Magnus animum: int
#     Folic Acid: int
#     RobNY: int
#     Al tally: int
#     DoriSmith: int
#     DropDeadGorgias: int
#     Lambanog: int
#     Asterion: int
#     CharlieEchoTango: int
#     Tiggerjay: int
#     HResearcher: int
#     Dr. Blofeld: int
#     WilliamH: int
#     Iamawesome800: int
#     Adjwilley: int
#     Abcdefghijklm: int
#     Runewiki777: int
#     VeryVerily: int
#     Bmusician: int
#     Mitchazenia: int
#     John Sloan: int
#     FD: int
#     Francium12: int
#     PumpkinSky: int
#     AKAF: int
#     CDThieme: int
#     -Ril-: int
#     Rich Farmbrough: int
#     Malcolmxl5: int
#     Smallman12q: int
#     Ucucha: int
#     Shimeru: int
#     Guest9999: int
#     Rosiestep: int
#     Anthony DiPierro: int
#     davidwr: int
#     Laser brain: int
#     ais523: int
#     Thebainer: int
#     Idont Havaname: int
#     Recurring dreams: int
#     Smurrayinchester: int
#     Docboat: int
#     Stalwart111: int
#     James500: int
#     jnothman: int
#     Dream Focus: int
#     JamesBWatson: int
#     Gary King: int
#     Improv: int
#     Bachrach44: int
#     Alansohn: int
#     Richwales: int
#     Viriditas: int
#     John Broughton: int
#     Shultz IV: int
#     VasileGaburici: int
#     Causesobad: int
#     Sietse Snel: int
#     Diannaa: int
#     Golbez: int
#     Bradeos Graphon: int
#     Moink: int
#     TheProf07: int
#     Crotalus horridus: int
#     No Guru: int
#     Sky Attacker: int
#     Cullen328: int
#     Glen S: int
#     Patstuart: int
#     Wadester16: int
#     Los Angeles Angels of Anaheim Fan: int
#     Salvio  giuliano: int
#     GrahamColm: int
#     Electriccatfish2: int
#     TimPope: int
#     Mediran: int
#     Nickptar: int
#     Howabout1: int
#     11: int
#     Gamaliel: int
#     MoRsE: int
#     Krashlandon: int
#     Turnstep: int
#     Joke137: int
#     Bali ultimate: int
#     SuperMachine: int
#     Joelr31: int
#     Sirex98: int
#     IceUnshattered: int
#     II MusLiM HyBRiD II: int
#     Konstable: int
#     Unfocused: int
#     Ginkgo100: int
#     Guðsþegn: int
#     thedemonhog: int
#     Fvasconcellos: int
#     Pmlineditor: int
#     mikkalai: int
#     Veesicle: int
#     Adam Bishop: int
#     Cenarium: int
#     DHMO: int
#     Rhobite: int
#     E: int
#     Deepujoseph: int
#     Jack Merridew: int
#     Tachikoma: int
#     AYArktos: int
#     QuiteUnusual: int
#     Acroterion: int
#     Bwithh: int
#     Thumperward: int
#     Filiocht: int
#     RadManCF: int
#     Power.corrupts: int
#     Raymond arritt: int
#     TSO1D: int
#     TedE: int
#     Deryck Chan: int
#     Oren0: int
#     Aminz: int
#     A7x: int
#     Grafikm fr: int
#     Dave souza: int
#     Mmeinhart: int
#     *drew: int
#     Flyguy649: int
#     DGX: int
#     ebe123: int
#     Willmcw: int
#     Variable: int
#     Vassyana: int
#     Icelandic Hurricane: int
#     Gwen Gale: int
#     Fr33kman: int
#     The Joker: int
#     Silversmith: int
#     Lankybugger: int
#     MrX: int
#     Nmajdan: int
#     Doctorbruno: int
#     Parsecboy: int
#     Leidiot: int
#     freakofnurture: int
#     TheSpecialUser: int
#     Karanacs: int
#     LordSunday: int
#     MarkSweep: int
#     Alanbly: int
#     Σ: int
#     Ioeth: int
#     Where: int
#     Jeffpw: int
#     Gimmetrow: int
#     Pegasus1138: int
#     That Guy, From That Show!: int
#     Hit bull, win steak: int
#     Orioane: int
#     Stevey7788: int
#     All in: int
#     Anthony cfc: int
#     Terraxos: int
#     Jbmurray: int
#     Luna Santin: int
#     Rzuwig: int
#     E. Brown: int
#     DennyColt: int
#     Reflex Reaction: int
#     Royalguard11: int
#     WarthogDemon: int
#     Antonio Lopez: int
#     Dragon695: int
#     SoLando: int
#     {{{User: int
#     Doctree: int
#     Herostratus: int
#     LlamaAl: int
#     Aaron Brenneman: int
#     Carpet9: int
#     Skinny87: int
#     Department of Redundancy Department: int
#     TheoClarke: int
#     Crisco 1492: int
#     Flaming: int
#     AKMask: int
#     Echuck215: int
#     Pomte: int
#     Chairman S.: int
#     Merzbow: int
#     Puffin: int
#     Dabomb87: int
#     Fetofs: int
#     Sseballos: int
#     Legolost: int
#     Macys123: int
#     Gflores: int
#     Erik9: int
#     Freakofnurture: int
#     Gray62: int
#     Catfish Jim: int
#     tdxiang: int
#     Ryan Delaney: int
#     Relata refero: int
#     Kumioko: int
#     RoyBoy: int
#     Peter Damian: int
#     Lupo: int
#     KazakhPol: int
#     Capitalistroadster: int
#     Plato: int
#     Groggy Dice: int
#     Number 57: int
#     Spinach Dip: int
#     Giano II: int
#     Vibhijain: int
#     JavaTenor: int
#     blurpeace: int
#     Infrogmation: int
#     Xavexgoem: int
#     Tim Q. Wells: int
#     Tedder: int
#     RyRy: int
#     GraemeL: int
#     InShaneee: int
#     Toon05: int
#     Jarkeld: int
#     Xezbeth: int
#     Moncrief: int
#     Scott MacDonald: int
#     Dustimagic: int
#     AnonEMouse: int
#     Nandesuka: int
#     Truthkeeper88: int
#     Alan16: int
#     Callanecc: int
#     Corpx: int
#     T'Shael: int
#     JPD: int
#     Barkjon: int
#     Riley Huntley: int
#     Michig: int
#     Pursey: int
#     Geometry guy: int
#     Linuxerist: int
#     Fluffernutter: int
#     deeptrivia: int
#     Acather96: int
#     Aunt Entropy: int
#     Hu12: int
#     Pastordavid: int
#     Sam Korn: int
#     EddieSegoura: int
#     Meno25: int
#     Beetstra: int
#     EliminatorJR: int
#     Ashton1983: int
#     Redrocketboy: int
#     Lapinmies: int
#     Next-Genn-Gamer: int
#     New England: int
#     Accurizer: int
#     Tool2Die4: int
#     Dacium: int
#     Sluzzelin: int
#     Arminius: int
#     Strothra: int
#     Ks0stm: int
#     Floquenbeam: int
#     ContiE: int
#     Kmccoy: int
#     intelati: int
#     Wryspy: int
#     Hurricanefan25: int
#     Mkdw: int
#     Adam1213: int
#     IRWolfie-: int
#     Ancapp: int
#     Pundit: int
#     Demiurge1000: int
#     Mtmelendez: int
#     NrDg: int
#     Nathan Johnson: int
#     Pratyya Ghosh: int
#     Peregrine Fisher: int
#     RexxS: int
#     Phil Bridger: int
#     Ahonc: int
#     DanBealeCocks: int
#     CrnaGora: int
#     Nja247: int
#     Soxred93: int
#     Prom3th3an: int
#     Ferdiaob: int
#     Draicone: int
#     PMC: int
#     Crazytales: int
#     Heah: int
#     Buster7: int
#     TaborL: int
#     Lanky: int
#     Katefan0: int
#     Intoronto1125: int
#     Rune.welsh: int
#     Spinach Monster: int
#     Lawrencekhoo: int
#     Bedivere: int
#     Madman: int
#     Webclient101: int
#     Jon513: int
#     Willking1979: int
#     JimMillerJr: int
#     BozMo: int
#     zzuuzz: int
#     Tazerdadog: int
#     Errabee: int
#     NCurse: int
#     Holdenhurst: int
#     SoothingR: int
#     Ac1983fan: int
#     Thames: int
#     Kansan: int
#     Primate: int
#     Adrian Buehlmann: int
#     Beit Or: int
#     MrFizyx: int
#     Jpgordon: int
#     Celarnor: int
#     King Pickle: int
#     Coppertwig: int
#     Carom: int
#     Sannse: int
#     Dina: int
#     Dr Zen: int
#     Satori Son: int
#     Katarighe: int
#     TREYWiki: int
#     InDeBiz1: int
#     Catchpole: int
#     Sallicio: int
#     Moshe Constantine Hassan Al-Silverburg: int
#     Pakaran: int
#     Thatcher131: int
#     Hydroxonium: int
#     Nev1: int
#     GT: int
#     Oysterguitarist: int
#     Robth: int
#     Materialscientist: int
#     Sting au: int
#     Fridae'sDoom: int
#     Nathan: int
#     Lord Bob: int
#     Rigadoun: int
#     Micahmn: int
#     Ericorbit: int
#     Trevj: int
#     Shudde: int
#     Revolving Bugbear: int
#     Amalthea: int
#     Ali'i: int
#     thedjatclubrock: int
#     CO: int
#     Acps110: int
#     Centrx: int
#     NicholasTurnbull: int
#     TruPepitoM: int
#     Interiot: int
#     Hawkeye7: int
#     Stfg: int
#     Evadb: int
#     Od Mishehu: int
#     Frise: int
#     Lowellian: int
#     Mato: int
#     Leonard^Bloom: int
#     Graham87: int
#     Aquillion: int
#     Ynhockey: int
#     Thistheman: int
#     Palmiro: int
#     Hermione1980: int
#     MWOAP: int
#     Mdd4696: int
#     Strikeout Sister: int
#     Vsmith: int
#     INeverCry: int
#     Darth Panda: int
#     Quiddity: int
#     CattleGirl: int
#     UtherSRG: int
#     Trödel: int
#     TheCoffee: int
#     Jayen466: int
#     Egg Centric: int
#     Bzweebl: int
#     Lukep913: int
#     Dysprosia: int
#     ScottDavis: int
#     Kzrulzuall: int
#     KimvdLinde: int
#     fvw: int
#     GorillaWarfare: int
#     Irongargoyle: int
#     Ameliorate!: int
#     L'Aquatique: int
#     FrankTobia: int
#     SoxBot: int
#     Yunshui: int
#     Roadrunnerz45: int
#     Spellcast: int
#     Fritzpoll: int
#     Appleworm: int
#     MichaelLinnear: int
#     Preceding unsigned comment: int
#     Scott5114: int
#     Martijn Hoekstra: int
#     Letsdrinktea: int
#     Exploding Boy: int
#     Kntrabssi: int
#     Vacation9: int
#     Phoenix 15: int
#     Minimac94: int
#     Wikiacc: int
#     Jonathan: int
#     Stupid2: int
#     Wik: int
#     MindstormsKid: int
#     Dr Zak: int
#     True Pagan Warrior: int
#     Brownlee: int
#     Natalinasmpf: int
#     Coelacan: int
#     A8UDI: int
#     Chris.B: int
#     Mail2amitabha: int
#     Scobell302: int
#     Charitwo: int
#     Terrancommander: int
#     Lovetinkle: int
#     TParis00ap: int
#     Mr. Turcotte: int
#     Tim.bounceback: int
#     Sgeureka: int
#     Tbeatty: int
#     Jmundo: int
#     Scray: int
#     HGB: int
#     Ian13: int
#     Elonka: int
#     JesseW: int
#     Milowent: int
#     Mm40: int
#     SatuSuro: int
#     Kuyabribri: int
#     PaleAqua: int
#     Ron Ritzman: int
#     Myleslong: int
#     TheGeneralUser: int
#     CrazyInSane: int
#     First Light: int
#     Corvus cornix: int
#     Cholmes75: int
#     Ruslik0: int
#     Collectonian: int
#     AstroHurricane001: int
#     SunStar Net: int
#     Kudret abi: int
#     Ryulong: int
#     CTSWyneken: int
#     Dev920: int
#     ChazBeckett: int
#     Vejvančický: int
#     Sarahe: int
#     Matty the Damned: int
#     Mus Musculus: int
#     Pink Bull: int
#     DESiegel: int
#     Ssbohio: int
#     The Anonymouse: int
#     Duncharris: int
#     Merope: int
#     Tedernst: int
#     Xenon54: int
#     Aeon1006: int
#     Getcrunk: int
#     bookofjude: int
#     Werdnabot: int
#     Booksworm: int
#     MacMed: int
#     I'm Spartacus!: int
#     ClockworkSoul: int
#     ddstretch: int
#     Leithp: int
#     tone: int
#     DCI2026: int
#     Notedgrant: int
#     Ikip: int
#     StuffOfInterest: int
#     Amcbride: int
#     SimonP: int
#     Viajero: int
#     Samuel Blanning: int
#     theoneintraining: int
#     Marudubshinki: int
#     Lucasbfr: int
#     Cncmaster: int
#     TML: int
#     Ronk01: int
#     Oxymoron83: int
#     Citicat: int
#     Benc: int
#     Fainites: int
#     Somitho: int
#     Chasingsol: int
#     Leyo: int
#     ZappaOMati: int
#     D.M.N.: int
#     Noisy: int
#     MelbourneStar: int
#     Nat: int
#     macy: int
#     Filll: int
#     Hammersoft: int
#     Morbidthoughts: int
#     Sam Blacketer: int
#     Pepperpiggle: int
#     Channel R: int
#     Panyd: int
#     NawlinWiki: int
#     D-Day: int
#     Bahn Mi: int
#     Selmo: int
#     Canderous: int
#     ArchonMagnus: int
#     Tznkai: int
#     Gatoclass: int
#     Skier Dude: int
#     Drawn Some: int
#     SimonKSK: int
#     Resident Mario: int
#     Perl: int
#     Wolfman: int
#     Ianblair23: int
#     Yaf: int
#     Dryman: int
#     Blackcap: int
#     SonicChao: int
#     Jorgenev: int
#     thumperward: int
#     Edgarde: int
#     NYC JD: int
#     Universal Cereal Bus: int
#     M1ss1ontomars2k4: int
#     NAHID: int
#     Node ue: int
#     Zocky: int
#     Tvaughn05: int
#     Rockfang: int
#     Werdna: int
#     smoddy: int
#     Biruitorul: int
#     Smashville: int
#     Seth Ilys: int
#     IP69.226.103.13: int
#     Zordrac: int
#     DC: int
#     Jac16888: int
#     Ngb: int
#     KP Botany: int
#     Rlendog: int
#     Bryson109: int
#     Woggly: int
#     Mallanox: int
#     Saluyot: int
#     Kate: int
#     Waggers: int
#     Ancient Apparition: int
#     Markalexander100: int
#     Dbraceyrules: int
#     Clayoquot: int
#     Pyfan: int
#     EivindFOyangen: int
#     Fish and karate: int
#     R613vlu: int
#     Bstone: int
#     Shyamal: int
#     Roadmr: int
#     Monobi: int
#     Ymblanter: int
#     Smmurphy: int
#     Pookeo9: int
#     Zginder: int
#     Tango: int
#     EdwinHJ: int
#     Kraxler: int
#     Dirtlawyer1: int
#     ReyBrujo: int
#     Fram: int
#     Silsor: int
#     Phils: int
#     Vicenarian: int
#     Bonaparte: int
#     Mayalld: int
#     Arwel Parry: int
#     Trevor macinnis: int
#     Merecat: int
#     Type O Spud: int
#     Karl Meier: int
#     DDima: int
#     Dpbsmith: int
#     Lear's Fool: int
#     AySz88: int
#     Save Us 229: int
#     Skater: int
#     The Gerg: int
#     Sebastiankessel: int
#     Imaglang: int
#     J04n: int
#     Eliz81: int
#     SaxTeacher: int
#     Slp1: int
#     BigDunc: int
#     Matheuler: int
#     Javert: int
#     BenAveling: int
#     Wronkiew: int
#     cocoaguy: int
#     Captainj: int
#     Richard0612: int
#     Wikiwind: int
#     Irishpunktom: int
#     The Fat Man Who Never Came Back: int
#     Brambleberry of RiverClan: int
#     StabiloBoss: int
#     C678: int
#     Armedblowfish: int
#     PinchasC: int
#     PirateSmackK: int
#     LuK3: int
#     Selket: int
#     Nouniquenames: int
#     Audacity: int
#     Brendenhull: int
#     Jon Harald Søby: int
#     Bigtop: int
#     Firestorm: int
#     JGHowes: int
#     Ched: int
#     Allmightyduck: int
#     Hexagon1: int
#     ResidentAnthropologist: int
#     Dakpowers: int
#     Ed Fitzgerald: int
#     VictorianMutant: int
#     Fly by Night: int
#     Netkinetic: int
#     Iridescenti: int
#     JuneGloom07: int
#     Crazymonkey1123: int
#     Storkk: int
#     TeaDrinker: int
#     Seraphim Whipp: int
#     Mono: int
#     Blurpeace: int
#     Paragon12321: int
#     AndyZ: int
#     UpstateNYer: int
#     7107delicious: int
#     David Underdown: int
#     Betacommand: int
#     Jhfireboy: int
#     Aucaman: int
#     Madman bum and angel: int
#     R. Baley: int
#     Connel MacKenzie: int
#     The Earwig: int
#     LukeTheSpook: int
#     Kookykman: int
#     WillowW: int
#     Ann Heneghan: int
#     Babajobu: int
#     Peruvianllama: int
#     2over0: int
#     Kyoko: int
#     Businessman332211: int
#     Logical Premise: int
#     Heimstern Läufer: int
#     Salaskan: int
#     Cool Cat: int
#     Wayward: int
#     Ksy92003: int
#     PxMa: int
#     HIZKIAH: int
#     SOADLuver: int
#     Elockid: int
#     AntonioMartin: int
#     MegamanZero: int
#     Trebor: int
#     Fusionmix: int
#     Rick Block: int
#     Imageboy1: int
#     Closedmouth: int
#     Renata3: int
#     Sp33dyphil: int
#     Strike Eagle: int
#     Widr: int
#     Travellingcari: int
#     Avenue: int
#     Onnaghar: int
#     Pcb21: int
#     Rd232: int
#     Gggh: int
#     Parent5446: int
#     Scorpion0422: int
#     Lucid: int
#     Lacrimosus: int
#     Arnon Chaffin: int
#     Batmanand: int
#     MartinRe: int
#     CIreland: int
#     GangstaEB: int
#     Ocatecir: int
#     Likeminas: int
#     Philwelch: int
#     Bbb23: int
#     The Evil Spartan: int
#     Metros: int
#     Jerry: int
#     SMasters: int
#     Perseus, Son of Zeus: int
#     Ijanderson977: int
#     Hesperian: int
#     Badbilltucker: int
#     Nunh-huh: int
#     Érico Júnior Wouters: int
#     TomTheHand: int
#     Theseeker4: int
#     John F. Lewis: int
#     Status: int
#     Kevin Breitenstein: int
#     Antivenin: int
#     Chase me ladies, I'm the Cavalry: int
#     Ale jrb: int
#     Simetrical: int
#     Daniel Olsen: int
#     Klonimus: int
#     Excirial: int
#     Ansell: int
#     Dragon's Blood: int
#     Christian Nurtsch: int
#     TheWeakWilled: int
#     Zagalejo: int
#     Jedd Raynier: int
#     Sjones23: int
#     Kusonaga: int
#     Deor: int
#     Jorgath: int
#     Blanchardb: int
#     TKE: int
#     bmicomp: int
#     SpuriousQ: int
#     Cimon avaro: int
#     Ice Cold Beer: int
#     Cyan: int
#     Nadavspi: int
#     Duja: int
#     Artichoker: int
#     Poetlister: int
#     elcobbola: int
#     Feezo: int
#     Fuzheado: int
#     Geo.plrd: int
#     ikiroid: int
#     Aren't I Obscure?: int
#     Manning Bartlett: int
#     Doc Tropics: int
#     Finalnight: int
#     ktr101: int
#     Osidge: int
#     Qp10qp: int
#     Pan Gerwazy: int
#     BrianY: int
#     Seddon: int
#     MJCdetroit: int
#     Kilbad: int
#     Ohconfucius: int
#     zanimum: int
#     L (usurped): int
#     ShortJason: int
#     Anomo: int
#     6SJ7: int
#     Dipankan001: int
#     Terrillja: int
#     CesarB: int
#     Daycd: int
#     OohBunnies!: int
#     Wafulz: int
#     Gsl: int
#     Greswik: int
#     Bigtimepeace: int
#     Ancheta Wis: int
#     Vengeful Cynic: int
#     Yahel Guhan: int
#     Paul August: int
#     j: int
#     Phil Boswell: int
#     Literaturegeek: int
#     Mastrchf91: int
#     Wangi: int
#     NiciVampireHeart: int
#     Killiondude: int
#     DukeOfDuchessStreet: int
#     VX: int
#     Vulcanstar6: int
#     Renaissancee: int
#     Kungming2: int
#     Doug: int
#     Dragomiloff: int
#     Hemmingsen: int
#     Throwaway85: int
#     Goodnightmush: int
#     Hbdragon88: int
#     Lakers: int
#     TharsHammar: int
#     Jackrm: int
#     Llywrch: int
#     Fvw: int
#     5 albert square: int
#     Matt.T: int
#     CactusWriter: int
#     B.wilson: int
#     .V.: int
#     Salih: int
#     HolyRomanEmperor: int
#     Binksternet: int
#     Cyp: int
#     Tim!: int
#     Coasterlover1994: int
#     Cunard: int
#     Raichu: int
#     Reedy Boy: int
#     Irishguy: int
#     auawise: int
#     1234r00t: int
#     Wiglaf: int
#     LadyofShalott: int
#     Foxj: int
#     Ardenn: int
#     Ali K: int
#     Arf!: int
#     Wayne Olajuwon: int
#     Pjacobi: int
#     Bradv: int
#     Paranomia: int
#     Whitstable: int
#     Iamunknown: int
#     Derktar: int
#     Versus22: int
#     CJ: int
#     CWY2190: int
#     Achromatic: int
#     Violetriga: int
#     MisterWiki: int
#     Markovich292: int
#     Apoc2400: int
#     LAX: int
#     Warlordjohncarter: int
#     AliveFreeHappy: int
#     CadenS: int
#     Thright: int
#     CountyLemonade: int
#     CComMack: int
#     Fawcett5: int
#     Cyrius: int
#     Ned Scott: int
#     Stormtracker94: int
#     BirgitteSB: int
#     Kotra: int
#     Jmabel: int
#     Crockspot: int
#     Ouro: int
#     Admiral Norton: int
#     Caknuck: int
#     King of the North East: int
#     EncycloPetey: int
#     R. fiend: int
#     Seed 2.0: int
#     Barryob: int
#     Moriori: int
#     Sp3000: int
#     Vertium: int
#     Armon: int
#     Staffwaterboy: int
#     Kafka Liz: int
#     Staberinde: int
#     Hex: int
#     SMcCandlish: int
#     Frazzydee: int
#     Grondemar: int
#     Fernando Rizo: int
#     Wagino 20100516: int
#     GChriss: int
#     Samir grover: int
#     PseudoSudo: int
#     Jayron32: int
#     St.daniel: int
#     MauchoEagle: int
#     Kurykh: int
#     Jeanenawhitney: int
#     LeCour: int
#     Slrubenstein: int
#     Klemen Kocjancic: int
#     People Powered: int
#     Jmh649: int
#     Jared Hunt: int
#     Matty: int
#     Hurricanehink: int
#     Ruairidi: int
#     Diez2: int
#     ChrisGualtieri: int
#     Crazynas: int
#     PullToOpen: int
#     Trevor MacInnis: int
#     John Lake: int
#     Aboutmovies: int
#     Punkmorten: int
#     Hildanknight: int
#     I: int
#     Robert McClenon: int
#     Vildricianus: int
#     Joe Chill: int
#     Zerida: int
#     LindsayH: int
#     Extranet: int
#     Zoz: int
#     MelanieN: int
#     Delirium: int
#     Pádraic MacUidhir: int
#     Amerique: int
#     Bottesini: int
#     Polly: int
#     Dainomite: int
#     TerriersFan: int
#     General Eisenhower: int
#     Mike Cline: int
#     2: int
#     Ginbot86: int
#     Phr: int
#     SamuelWantman: int
#     Moni3: int
#     Extreme Unction: int
#     Korruski: int
#     Fredrik: int
#     Ferkelparade: int
#     Funnybunny: int
#     TerrenceandPhillip: int
#     Dravecky: int
#     Mukadderat: int
#     Compwhizii: int
#     Johnuniq: int
#     Lord Emsworth: int
#     Cprompt: int
#     Ajbpearce: int
#     RobertG: int
#     Wikimachine: int
#     Neskaya: int
#     Chezhiyan: int
#     Susvolans: int
#     Jd027: int
#     JoeSmack: int
#     f-m-t: int
#     Cardamon: int
#     BarkingFish: int
#     Parrot of Doom: int
#     Rudjek: int
#     Oldwindybear: int
#     MisterHand: int
#     PRueda29: int
#     TheIslander: int
#     Jarry1250: int
#     Appletrees: int
#     Dr Debug: int
#     Bling-chav: int
#     Axiomm: int
#     Frood: int
#     John Vandenberg: int
#     Cleared as filed: int
#     Netsnipe: int
#     NortyNort: int
# ...
#     L1AM: int
#     King Dracula: int
#     Castellanet: int
#     Hoverfish: int
#     Mutebutton: int
#     FreelanceWizard: int
#     Keepsleeping: int
#     BScar23625: int
#     PPGMD: int
#     Jecowa: int
#     Good Intentions: int
#     Sherool: int
#     Dussst: int
#     DAAdshead: int
#     Qwghlm: int
#     Ham: int
#     1568: int
#     Gretnagod: int
#     Nathan Ladd: int
#     Ghostieguide: int
#     Blarneytherinosaur: int
#     Nesher: int
#     Luckyherb: int
#     Ding Dong: int
#     Nationalparks: int
#     StarryEyes: int
#     Larry V: int
#     Uapatriot: int
#     Steelviper: int
#     Cmapm: int
#     Kazak: int
#     DenisRS: int
#     Nekto: int
#     .: int
#     Kmorozov: int
#     Wikiolap: int
#     Cornerbock: int
#     Starionwolf: int
#     Icewolf34: int
#     LarryQ: int
#     MrVacBob: int
#     David618: int
#     Archer7: int
#     Light current: int
#     SquidSK: int
#     DavidWBrooks: int
#     Garcilaso: int
#     Sycthos: int
#     Opark 77: int
#     Reswobslc: int
#     RandomP: int
#     Wisesabre: int
#     waqas.usman: int
#     Nil Einne: int
#     Son of a Peach: int
#     Tevildo: int
#     AnonGuy: int
#     Speciate: int
#     Audacitor: int
#     Hanoi Girl: int
#     HAL2008: int
#     Kesac: int
#     MWACHTENDONK: int
#     Yelsent: int
#     Paine: int
#     Mgiganteus1: int
#     Gen. von Klinkerhoffen: int
#     Novalis: int
#     Constantine: int
#     Phaunt: int
#     Cooldude\ 1988: int
#     Dhaifley: int
#     Tim62389: int
#     Munta: int
#     LADodgersAngelsfan: int
#     Dennymeta: int
#     Tazangel: int
#     Consumed Crustacean: int
#     Ng.j: int
#     Ytny: int
#     Coolcaesar: int
#     Ubiq: int
#     EdGl: int
#     Mahanga: int
#     Sugaar: int
#     Euskera: int
#     Danntm: int
#     Projectoxide: int
#     Brian Hamilton: int
#     DanBlackham: int
#     Rhythmnation2004: int
#     Ebyabe: int
#     Davidjk: int
#     Joe Wells: int
#     Carptrash: int
#     Harryboyles: int
#     THB: int
#     Emmelie: int
#     Reinis: int
#     Brian Olsen: int
#     JRG: int
#     Krisroe: int
#     Oggleboppiter: int
#     Bsayusd: int
#     H92: int
#     Wyv: int
#     Sarah sofía: int
#     Dethme0w: int
#     The obfuscated one: int
#     Darkfox123: int
#     Textorus: int
#     80.176.190.96: int
#     Yury Tarasievich: int
#     Bryan Tong Minh: int
#     Timichal: int
#     -Slash-: int
#     Arch NME: int
#     Keesiewonder: int
#     Freederick: int
#     Mikm: int
#     Stangbat: int
#     ShaleZero: int
#     Kushal one: int
#     LUCPOL: int
#     Indiver: int
#     Akut: int
#     Natkeeran: int
#     RajeshPandey: int
#     Desiphral: int
#     Asnatu wiki: int
#     Tlim7882: int
#     TheEditrix2: int
#     IFCAR: int
#     Fr33kMan: int
#     Dr.Gonzo: int
#     Ante Perkovic: int
#     Ceha: int
#     Laughing Man: int
#     Montenegro (MNE): int
#     Buffadren: int
#     Hadžija: int
#     Edin Sijercic: int
#     Paulcicero: int
#     Bbik: int
#     Tswsl1989: int
#     Sideshow Bob: int
#     HyperSushi21: int
#     Purple PowerRanger Eaterr: int
#     Pasonia: int
#     Vodomar: int
#     WikiSlasher: int
#     Tim Shuba: int
#     Wareh: int
#     Dbm11085: int
#     Teggles: int
#     Grim Revenant: int
#     Blutacker: int
#     Red: int
#     MacMad: int
#     Weikang: int
#     Montchav: int
#     Werideatdusk33: int
#     Geoffrey Mitchell: int
#     Jet123: int
#     DUDE42: int
#     068152: int
#     Baseballmes: int
#     Czac: int
#     Plumcouch: int
#     Ayatollah Rhobijnie: int
#     Mike Rosoft: int
#     CredoFromStart: int
#     WebHamster: int
#     Future54: int
#     Gandalf61: int
#     Editor at Large: int
#     Aspects: int
#     JSarek: int
#     Milo H Minderbinder: int
#     KJS77: int
#     Asteraki: int
#     Domitius: int
#     Cs: int
#     Fineday: int
#     Kashwialariski: int
#     Mrlob: int
#     Jim Pooele: int
#     Blueman102: int
#     Xenocide321: int
#     Weighted Companion Cube: int
#     Rise Above the Vile: int
#     AndreasWashington: int
#     HomeJames: int
#     Kheider: int
#     Isentropiclift: int
#     MyMii: int
#     Dreddnott: int
#     I'm a newcomer so please don't bite me: int
#     Pikminlover: int
#     TechWiz: int
#     Rebroad: int
#     Seventypercent: int
#     MrFirewall: int
#     S.Örvarr.S: int
#     Chuckfromchan: int
#     BrianWalker: int
#     Fnsnet: int
#     Olin: int
#     RogMcDog: int
#     Barfbagger: int
#     Guycalledryan: int
#     Edgerunner76: int
#     Snalwibma: int
#     Aiden Fisher: int
#     Sindell: int
#     Shagie: int
#     Dark Matter Narcosis: int
#     Tmtoulouse: int
#     Rob Pommer: int
#     Justinfr: int
#     Mickeystern: int
#     MikeWattHCP: int
#     Garrickdaft: int
#     Gnusmas: int
#     Numskll: int
#     Anonymous101: int
#     KenDenier: int
#     Nokhodi: int
#     Kurdo777: int
#     Mordicai: int
#     76: int
#     Josh Hamilton: int
#     NossB: int
#     Jaimaster: int
#     Feldspaar: int
#     Basil "Basil" Fawlty: int
#     Mooseter: int
#     Dar book: int
#     Hazillow: int
#     Vinh1313: int
#     Nobody of Consequence: int
#     Wildthing2022000: int
#     Director33: int
#     Thecurran: int
#     Jodykish: int
#     Simple Tastes: int
#     Falcon Kirtaran: int
#     Novidmarana: int
#     TomPhan: int
#     VandleBlaster: int
#     Wordbuilder: int
#     BillCJ: int
#     Shanner191: int
#     RAMChYLD: int
#     Electrical Experiment: int
#     mrg3105: int
#     Greggerr: int
#     Tymek: int
#     Megistias: int
#     Afil: int
#     Horlo: int
#     JamesLucas: int
#     Whpq: int
#     LordKenTheGreat: int
#     Brilliant Pebble: int
#     Bobamnertiopsis: int
#     PXk: int
#     Srevi: int
#     Dylant07: int
#     Atakdoug: int
#     Paul 1953: int
#     The Great Editor In Chief: int
#     DiamonDie: int
#     KC Panchal: int
#     Flibirigit: int
#     Vandalism destroyer: int
#     Tyler: int
#     SmithBlue: int
#     Blackworm: int
#     PSWG1920: int
#     Jsmith86: int
#     Illythr: int
#     Happy138: int
#     Ashley Y: int
#     Tegwarrior: int
#     Samsara noadmin: int
#     Mujinga: int
#     Geologyguy: int
#     Dchall1: int
#     Lobojo: int
#     Samurai Commuter: int
#     Frutti di Mare: int
#     Neutral Good: int
#     Samiharris: int
#     Islaammaged126: int
#     JeWay: int
#     Marty Rockatansky: int
#     Jaxfl: int
#     Mangoe: int
#     VengeancePrime: int
#     Spacepotato: int
#     Silverwolf85: int
#     ilikepie2221: int
#     DesperateAngel: int
#     Ro098: int
#     TrulyBlue: int
#     Adam Cuerden: int
#     Swirlboy39: int
#     Fairfieldfencer: int
#     Korny O'Near: int
#     Bovlb: int
#     Sillyfolkboy: int
#     IDangerMouse: int
#     Themadmullah: int
#     Mostlyharmless: int
#     BountyHunter2008: int
#     JohnnyMrNinja: int
#     Markreidyhp: int
#     Highfields: int
#     Thisisborin9: int
#     Qaddosh: int
#     -The Bold Guy-: int
#     Floaterfluss: int
#     Yoshaibo: int
#     FinFangFoom: int
#     X1987x: int
#     killerofkiller: int
#     Killerofkiller: int
#     v: int
#     Chafford: int
#     The SRS: int
#     Account created to post on Reference Desk: int
#     TheLetterM: int
#     CWii2: int
#     PaddyLeahy: int
#     Rracecarr: int
#     Skyezx: int
#     Sentriclecub: int
#     Canadian Paul: int
#     Megapen: int
#     Eatpeaches: int
#     Johnman239: int
#     Mbhiii: int
#     Pleasantville: int
#     EurekaLott: int
#     Rushyo: int
#     LeyteWolfer: int
#     Langloisrg: int
#     SameDayService: int
#     REDYVA: int
#     Wjmummert: int
#     Woonpton: int
#     Hello Control: int
#     Truthanado: int
#     Dc76: int
#     AdrianTM: int
#     Smitty494: int
#     Ken Thomas: int
#     Numyht: int
#     Sahilm: int
#     Rudie M.: int
#     Sniperz11: int
#     Edward Morgan Blake: int
#     Onefortyone: int
#     Greglocock: int
#     Einsteinewton: int
#     The Librarian: int
#     Natural hat trick: int
#     GeeAlice: int
#     Mistery Account: int
#     JavierMC: int
#     Osmanjunaid: int
#     Belanidia: int
#     MeegsC: int
#     Redeemer079: int
#     Djskein79: int
#     USS Hornet: int
#     The Rationalist: int
#     DanTheMan474: int
#     DanielEng: int
#     Anthon01: int
#     JNW: int
#     Stratosphere: int
#     JoshuaKuo: int
#     Wikiyuvraj: int
#     CounterFX: int
#     DearCatastropheWaitress: int
#     Funeral: int
#     Peter Fleet: int
#     Navnløs: int
#     StevenBlack: int
#     Tasc0: int
#     Charles: int
#     Sunsetsunrise: int
#     SimsFan: int
#     Yehudi: int
#     Jovin Lambton: int
#     VigilancePrime: int
#     Jonathan Cardy: int
#     SunDragon34: int
#     Nips: int
#     Jasy jatere: int
#     Elbutler: int
#     J. Van Meter: int
#     DaughterofSun: int
#     Eaglestorm: int
#     Nanami Kamimura: int
#     Truco9311: int
#     Master of Pies: int
#     tiny plastic Grey Knight: int
#     Esrever: int
#     NovaDog: int
#     1948remembered: int
#     PIO: int
#     Shibumi2: int
#     Npnunda: int
#     Alokprasad84: int
#     Caerwine: int
#     Waacstats: int
#     24.15.158.90: int
#     Red Phoenix: int
#     Roregan: int
#     Fred Plotz: int
#     CPacker: int
#     Jwanders: int
#     Dattebayo321: int
#     PeterStJohn: int
#     HG: int
#     Jaysweet: int
#     Albion moonlight: int
#     stormin' Foreman: int
#     Escape Orbit: int
#     Miamomimi: int
#     Scuro: int
#     Jakezing: int
#     Itfc%2Bcanes%3Dme: int
#     Elucidate: int
#     Nudve: int
#     Piz d'Es-Cha: int
#     Kanġi Oĥanko: int
#     StaticGull: int
#     Jacob696: int
#     AlexNebraska: int
#     Mellie: int
#     Str4nd: int
#     Milk's Favorite Public Account: int
#     Gopal81: int
#     Irmela: int
#     Tomruen: int
#     DCary: int
#     Ursasapien: int
#     Yellowbeard: int
#     Testmasterflex: int
#     Pondle: int
#     Brichcja: int
#     Lokyz: int
#     Moosester: int
#     FaithF: int
#     Stanstaple: int
#     Carter: int
#     Nat Miller: int
#     Restepc: int
#     -jha-: int
#     Historiograf: int
#     Steschke: int
#     Raboe001: int
#     GGG65: int
#     Police,Mad,Jack: int
#     Yurei-eggtart: int
#     Dahliarose: int
#     Guerilla In Tha Mist: int
#     Andrew Kelly: int
#     Carba: int
#     No Hollaback Girl: int
#     Black Knight takes White Queen: int
#     PlusDrawn: int
#     Maxschmelling: int
#     Tharnton345: int
#     VegitaU: int
#     Inclusionist: int
#     Blackadam2: int
#     Bignole: int
#     shoeofdeath: int
#     pd THOR: int
#     Matthew R Dunn: int
#     KS: int
#     Ziphon: int
#     BigHairRef: int
#     JC Petit: int
#     Bennose: int
#     Jaymacdonald: int
#     nneonneo: int
#     UberScienceNerd: int
#     Dhatfield: int
#     Willsmith3: int
#     SamanthaFox27: int
#     Pfrancois: int
#     Sfd1905: int
#     Cro0016: int
#     Freqsh0: int
#     Raddude50: int
#     Eahiv: int
#     Fg2: int
#     Bendono: int
#     Brian R Hunter: int
#     OptimistBen: int
#     Speakermeonce: int
#     Cyrus XIII: int
#     Avineshjose: int
#     KDerrida: int
#     Bad Monk3y: int
#     Gordonofcartoon: int
#     SweetCarmen: int
#     Eddie Guimont: int
#     Samorchard: int
#     Jnavas: int
#     Digby Tantrum: int
#     Claudevsq: int
#     Thesaddestday: int
#     MMAfan2007: int
#     Tuckdogg: int
#     S.dedalus: int
#     Grumpygrumpy: int
#     RandalSchwartz: int
#     MrWhich: int
#     Joevanisland: int
#     PHG: int
#     MaximvsDecimvs: int
#     DGrimshaw: int
#     Saoshyant: int
#     Folken de Fanel: int
#     thesydneyknowitall: int
#     Asyndeton: int
#     mcr616: int
#     HammerHeadHuman: int
#     Wikipedialuva: int
#     Pretty Green: int
#     Professor marginalia: int
#     Robert Ullmann: int
#     Duke o Puke: int
#     GentlemanGhost: int
#     64.230.2.27: int
#     Stephen Turner: int
#     AllynJ: int
#     here: int
#     Yamara: int
#     Wingsandsword: int
#     Bass fishing physicist: int
#     Willy, your mate: int
#     Pill-: int
#     Callipides: int
#     Polarlys: int
#     HBow3: int
#     Julius1990: int
#     Marcus Cyron: int
#     Olei: int
#     C-M: int
#     Seewolf: int
#     Felix Stember: int
#     Primus von Quack: int
#     Ra'ike: int
#     Schwalbe: int
#     Jón: int
#     PDD: int
#     Miskwito: int
#     Brian Josephson: int
#     Roseapple: int
#     Dradin: int
#     Solar: int
#     Atsakiris: int
#     Cosmokazi: int
#     DevAlt: int
#     Q Original: int
#     Sushant gupta: int
#     Bbwlover: int
#     Jeff Defender: int
#     NL-Ninane: int
#     Vlad fedorov: int
#     Abu ali: int
#     Icerinkprincess: int
#     Anietor: int
#     UnitedStatesian: int
#     HPJoker: int
#     Seans Potato Business: int
#     OnaTutors: int
#     RWR8189: int
#     Metros235: int
#     Dozenist: int
#     WikiSpaceboy: int
#     Khodavand: int
#     Hyperbole: int
#     Chicocvenancio: int
#     Galactor213: int
#     Suva: int
#     Shutterbug: int
#     Misou: int
#     Parishan: int
#     Lukejon1995: int
#     ShelfSkewed: int
#     Callelinea: int
#     Lima: int
#     Michaelsanders: int
#     Matthuxtable: int
#     JFreeman: int
#     TheNudge: int
#     Edtropolis: int
#     Patricknoddy: int
#     Vpopescu: int
#     Rray: int
#     iicatsii: int
#     Father Goose: int
#     Rat at WikiFur: int
#     Kaly99: int
#     Mrjingjing: int
#     Aivazovsky: int
#     Libertyville: int
#     Cao Wei: int
#     RPIRED: int
#     Kijog: int
#     Marcin Suwalczan: int
#     General Idea: int
#     DeanHinnen: int
#     Asperal: int
#     Arcfrk: int
#     Xevious: int
#     TheFearow: int
#     Disneyfreak96: int
#     Scottydude: int
#     Steele: int
#     Blood Red Sandman: int
#     Dalillama: int
#     Archtrain: int
#     Yamakiri on Firefox: int
#     Dr mindbender: int
#     SynKobiety: int
#     Keefer4: int
#     Tomas417: int
#     The dark lord trombonator: int
#     Crownofworms: int
#     HubmaN: int
#     Boris 1991: int
#     Geohevy: int
#     Aarktica: int
#     Jake R-12: int
#     Bryan: int
#     SiobhanHansa: int
#     Bfissa: int
#     Matthew2c4u: int
#     D Mac Con Uladh: int
#     Trey56: int
#     Eternal dragon: int
#     Xiutwel: int
#     Mainemainer: int
#     Jasper33: int
#     Qxz: int
#     Stemonitis: int
#     Jezebel Parks: int
#     Prester John: int
#     Prestonmcconkie: int
#     Leprechaun99: int
#     Ism schism: int
#     Natsayhi: int
#     Kubek15: int
#     Viskonsas: int
#     Bobby fletcher: int
#     Futurebird: int
#     Goo2you: int
#     Friarslantern: int
#     PoinDexta1: int
#     Adam Pirolo: int
#     Hendry Little: int
#     Vonita: int
#     Kakama5: int
#     Armanaziz: int
#     C.Logan: int
#     Qjuad: int
#     P3net: int
#     wrp103: int
#     Ralhazzaa: int
#     Asabbagh: int
#     Rye1967: int
#     Djegan: int
#     NickW557: int
#     Abtract: int
#     James.Spudeman: int
#     L: int
#     Hermione is a dude: int
#     CloudNine: int
#     Schlamniel: int
#     Ds.mt: int
#     Sparkit: int
#     Aaron Bowen: int
#     O.Waqfi: int
#     Quek157: int
#     Jrphayes: int
#     Alinnisawest: int
#     Omghgomg: int
#     Amanniste: int
#     Nneonneo: int
#     Spell4yr: int
#     5faizan: int
#     SeanMD80: int
#     Dougie WII: int
#     Xbones1000: int
#     Bearian'sBooties: int
#     Sbowers3: int
#     Lucy-marie: int
#     Hereford: int
#     כתר: int
#     Sebleouf: int
#     Politizer: int
#     Sister Endorphina: int
#     Chubbles: int
#     Schuym1: int
#     Halosean: int
#     Leeboyge: int
#     Togepi 987: int
#     El Quebrado: int
#     S-pac54: int
#     Isaacsf: int
#     Fogster: int
#     AWeenieMan: int
#     Duck of Luke: int
#     Traditional unionist: int
#     TheDaveRoss: int
#     Mind meal: int
#     Craw-daddy: int
#     Mcferran: int
#     Pawnkingthree: int
#     Piemanmoo: int
#     Import007: int
#     TigranTheGreat: int
#     Banzai777: int
#     Shaericell: int
#     Novelbank: int
#     David Sher: int
#     Feddhicks: int
#     Fneep: int
#     Two-Sixteen: int
#     ArthurWeasley: int
#     Luffy487: int
#     Pr4ever: int
#     Diego: int
#     Qyd: int
#     RandomOrca2: int
#     Pdeitiker: int
#     Fitzpatrickjm: int
#     Zachary: int
#     oysterguitarist: int
#     VectorPosse: int
#     DavidCBryant: int
#     TheLateDentarthurdent: int
#     Taemyr: int
#     Turgidson: int
#     Dominus: int
#     AndrewGNF: int
#     Omegatron: int
#     Descendall: int
#     Canadianshoper: int
#     Tompw: int
#     Brimba: int
#     GenghizRat: int
#     drunkenmonkey: int
#     Hannah K.: int
#     Killing sparrows: int
#     The Boy that time forgot: int
#     Thunderhead1: int
#     HarrisX: int
#     aliasd: int
#     Aktron: int
#     Mbc362: int
#     Orsini: int
#     Russeasby: int
#     Bungle: int
#     Nineteenninetyfour: int
#     William Pembroke: int
#     Chronic The Wedgehog: int
#     Defender 911: int
#     Canticle: int
#     HumanThing: int
#     Hirak 99: int
#     ChrisDHDR: int
#     Arubiez: int
#     Zanorath: int
#     Tommyboy1334: int
#     Stlemur: int
#     BalanceRestored: int
#     NeoNerd: int
#     snowolfd4: int
#     CygnetSaIad: int
#     Reason turns rancid: int
#     behmod: int
#     Atabek: int
#     Xtreme racer: int
#     James D. Forrester: int
#     Makuro: int
#     YellowAssessmentMonkey: int
#     Benplowman: int
#     xyzzy n: int
#     Nunquam Dormio: int
#     Eastlaw: int
#     Yossiea: int
#     P.wormer: int
#     Nydigoveth: int
#     directed: bool
# VERTEX
#     no properties
# EDGE
#     no properties

# %% [markdown]
# #### ajuste as propriedades visuais do grafo

# %%
# mudar a cor de fundo do grafo
r.graph(color=0xffffff)


# mudar a cor e o tamanho dos vértices
r.vertex_default(color=0x000000, size=2)

# mudar a cor, a espessura e a curvatura das arestas
r.edge_default(color=0x000000, width=3, curve1=2, curve2=2)
# Out:
#         <div id="9StJYS9wRG3Hnnr7A8hCCv"></div>
#         <script>netpixi.call('9StJYS9wRG3Hnnr7A8hCCv', 'gCDagsxJuhJ9uGDFyyHwRj', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJncmFwaCI6IHsiY29sb3IiOiAxNjc3NzIxNX19fQo=');</script>
#         <div id="77b6pXa22A4fEyfU9akkbN"></div>
#         <script>netpixi.call('77b6pXa22A4fEyfU9akkbN', 'gCDagsxJuhJ9uGDFyyHwRj', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJ2ZXJ0ZXgiOiB7ImNvbG9yIjogMCwgInNpemUiOiAyfX19Cg==');</script>
#         <div id="GiXLc9LJeSniF2Zkt3YgvE"></div>
#         <script>netpixi.call('GiXLc9LJeSniF2Zkt3YgvE', 'gCDagsxJuhJ9uGDFyyHwRj', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJlZGdlIjogeyJjb2xvciI6IDAsICJ3aWR0aCI6IDMsICJjdXJ2ZTEiOiAyLCAiY3VydmUyIjogMn19fQo=');</script>

# %%
#número de vértices
n = g.num_vertices()
print('O número de vértices é {0}'.format(n))
# Out:
# O número de vértices é 10415

# %%
from graph_tool import centrality

bc, _ = centrality.betweenness(g)
lista_zero_betwenness=[]
contador = 0
for value in bc:
    if value ==0:
        lista_zero_betwenness.append(contador)
    contador += 1
    
print(len(lista_zero_betwenness))
# Out:
# 6966

# %%
g.add_vp('betweenness', bc)

# %%
gt_data(g)
# Out:
#                  betweenness
# id
# Unknown         0.000000e+00
# Siva1979        9.221606e-09
# Mailer diablo   0.000000e+00
# Merovingian     9.221606e-09
# Wizardman       0.000000e+00
# ...                      ...
# Nunquam Dormio  9.221606e-09
# Eastlaw         0.000000e+00
# Yossiea         0.000000e+00
# P.wormer        9.221606e-09
# Nydigoveth      0.000000e+00
#
# [10415 rows x 1 columns]

# %%
r.vertex_set_key('id')
r.vertex_scale('betweenness', 10, 50)
# Out:
#         <div id="JxNNPxzDbLbLRCTfMJJibF"></div>
#         <script>netpixi.call('JxNNPxzDbLbLRCTfMJJibF', 'gCDagsxJuhJ9uGDFyyHwRj', 'setGraph', 'eyJ0eXBlIjogInZlcnRleCIsICJwcm9wcyI6IHsic3JjIjogImlkIiwgImRzdCI6ICJfa2V5In19Cg==');</script>
#         <div id="SfSNG9m4NxffPpuTHA7VD9"></div>
#         <script>netpixi.call('SfSNG9m4NxffPpuTHA7VD9', 'gCDagsxJuhJ9uGDFyyHwRj', 'normalizeGraph', 'eyJ0eXBlIjogInZlcnRleCIsICJwcm9wcyI6IHsic3JjIjogImJldHdlZW5uZXNzIiwgIm1pbiI6IDEwLCAibWF4IjogNTB9fQo=');</script>
